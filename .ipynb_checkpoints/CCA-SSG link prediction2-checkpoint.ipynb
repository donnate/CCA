# %%
from model import CCA_SSG, LogReg
from aug import random_aug
from dataset import load

import numpy as np
import torch as th
import torch.nn as nn

import warnings

warnings.filterwarnings('ignore')

from sklearn.metrics import roc_auc_score, average_precision_score
from util import mask_test_edges_dgl
import dgl
import torch.nn.functional as F
import pdb
# Out:
# Using backend: pytorch

# %%
# parser.add_argument('--gpu', type=int, default=0, help='GPU index.')
# parser.add_argument('--use_mlp', action='store_true', default=False, help='Use MLP instead of GNN')

# %%
def get_scores(edges_pos, edges_neg, adj_rec):
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    adj_rec = adj_rec.cpu()
    # Predict on test set of edges
    preds = []
    for e in edges_pos:
        preds.append(sigmoid(adj_rec[e[0], e[1]].item()))

    preds_neg = []
    for e in edges_neg:
        preds_neg.append(sigmoid(adj_rec[e[0], e[1]].data))

    preds_all = np.hstack([preds, preds_neg])
    labels_all = np.hstack([np.ones(len(preds)), np.zeros(len(preds_neg))])
    roc_score = roc_auc_score(labels_all, preds_all)
    ap_score = average_precision_score(labels_all, preds_all)

    return roc_score, ap_score

# %%
graph, feat, labels, num_class, train_idx, val_idx, test_idx = load('cora')
adj_orig = graph.adj().to_dense()
train_edge_idx, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_dgl(graph, adj_orig)

# create train graph
train_edge_idx = th.tensor(train_edge_idx)
train_graph = dgl.edge_subgraph(graph, train_edge_idx, preserve_nodes=True)

# add self loop
#train_graph = dgl.remove_self_loop(train_graph)
#train_graph = dgl.add_self_loop(train_graph)
#n_edges = train_graph.number_of_edges()
#adj = train_graph.adjacency_matrix().to_dense()

# normalization
#degs = train_graph.in_degrees().float()
#norm = th.pow(degs, -0.5)
#norm[th.isinf(norm)] = 0
#train_graph.ndata['norm'] = norm.unsqueeze(1)
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.

# %%
# graph, feat, labels, num_class, train_idx, val_idx, test_idx = load('cora')

in_dim = feat.shape[1]

hid_dim = 512
out_dim = 512
n_layers = 2

model = CCA_SSG(in_dim, hid_dim, out_dim, n_layers, use_mlp=False)
lr1 = 1e-3 
wd1 = 0
optimizer = th.optim.Adam(model.parameters(), lr=lr1, weight_decay=wd1)

N = graph.number_of_nodes()

for epoch in range(100):
    model.train()
    optimizer.zero_grad()
    
    dfr = 0.2
    der = 0.2

    graph1, feat1 = random_aug(graph, feat, 0.2, 0.2)
    graph2, feat2 = random_aug(graph, feat, 0.2, 0.2)

    graph1 = graph1.add_self_loop()
    graph2 = graph2.add_self_loop()

    z1, z2 = model(graph1, feat1, graph2, feat2)

    c = th.mm(z1.T, z2)
    c1 = th.mm(z1.T, z1)
    c2 = th.mm(z2.T, z2)

    c = c / N
    c1 = c1 / N
    c2 = c2 / N

    loss_inv = -th.diagonal(c).sum()
    iden = th.tensor(np.eye(c.shape[0]))
    loss_dec1 = (iden - c1).pow(2).sum()
    loss_dec2 = (iden - c2).pow(2).sum()
    
    lambd = 1e-3
    
    loss = loss_inv + lambd * (loss_dec1 + loss_dec2)

    loss.backward()
    optimizer.step()

    print('Epoch={:03d}, loss={:.4f}'.format(epoch, loss.item()))
# Out:
# Epoch=000, loss=-359.3125
# Epoch=001, loss=-351.0300
# Epoch=002, loss=-352.7984
# Epoch=003, loss=-358.8241
# Epoch=004, loss=-396.2486
# Epoch=005, loss=-399.4687
# Epoch=006, loss=-377.7650
# Epoch=007, loss=-408.0907
# Epoch=008, loss=-401.6025
# Epoch=009, loss=-413.8253
# Epoch=010, loss=-402.4824
# Epoch=011, loss=-404.1632
# Epoch=012, loss=-415.7970
# Epoch=013, loss=-408.9606
# Epoch=014, loss=-412.8656
# Epoch=015, loss=-416.9501
# Epoch=016, loss=-420.7227
# Epoch=017, loss=-422.6843
# Epoch=018, loss=-431.5959
# Epoch=019, loss=-419.6221
# Epoch=020, loss=-434.7444
# Epoch=021, loss=-426.3523
# Epoch=022, loss=-428.5444
# Epoch=023, loss=-430.0735
# Epoch=024, loss=-431.1600
# Epoch=025, loss=-439.5212
# Epoch=026, loss=-432.6340
# Epoch=027, loss=-434.9827
# Epoch=028, loss=-435.3034
# Epoch=029, loss=-436.5374
# Epoch=030, loss=-437.5219
# Epoch=031, loss=-441.5498
# Epoch=032, loss=-440.2833
# Epoch=033, loss=-445.4271
# Epoch=034, loss=-437.4046
# Epoch=035, loss=-439.2170
# Epoch=036, loss=-445.2807
# Epoch=037, loss=-444.1143
# Epoch=038, loss=-440.5540
# Epoch=039, loss=-436.5673
# Epoch=040, loss=-442.3697
# Epoch=041, loss=-450.2850
# Epoch=042, loss=-449.9695
# Epoch=043, loss=-448.9502
# Epoch=044, loss=-438.6576
# Epoch=045, loss=-442.4442
# Epoch=046, loss=-444.2408
# Epoch=047, loss=-450.5217
# Epoch=048, loss=-451.2567
# Epoch=049, loss=-448.9417
# Epoch=050, loss=-451.4302
# Epoch=051, loss=-450.2055
# Epoch=052, loss=-449.4665
# Epoch=053, loss=-448.7901
# Epoch=054, loss=-450.9230
# Epoch=055, loss=-449.9440
# Epoch=056, loss=-450.2057
# Epoch=057, loss=-449.9555
# Epoch=058, loss=-450.5947
# Epoch=059, loss=-451.9317
# Epoch=060, loss=-450.9737
# Epoch=061, loss=-453.8818
# Epoch=062, loss=-453.4691
# Epoch=063, loss=-451.9065
# Epoch=064, loss=-447.7987
# Epoch=065, loss=-453.6152
# Epoch=066, loss=-452.4167
# Epoch=067, loss=-454.3298
# Epoch=068, loss=-455.6032
# Epoch=069, loss=-455.7116
# Epoch=070, loss=-456.9790
# Epoch=071, loss=-455.4218
# Epoch=072, loss=-456.7172
# Epoch=073, loss=-455.4170
# Epoch=074, loss=-451.8832
# Epoch=075, loss=-456.8111
# Epoch=076, loss=-459.4894
# Epoch=077, loss=-455.4417
# Epoch=078, loss=-452.7647
# Epoch=079, loss=-456.4899
# Epoch=080, loss=-454.6701
# Epoch=081, loss=-457.6534
# Epoch=082, loss=-457.9776
# Epoch=083, loss=-457.4117
# Epoch=084, loss=-456.7752
# Epoch=085, loss=-460.7859
# Epoch=086, loss=-458.4999
# Epoch=087, loss=-459.1533
# Epoch=088, loss=-455.0444
# Epoch=089, loss=-456.5766
# Epoch=090, loss=-458.1583
# Epoch=091, loss=-462.1674
# Epoch=092, loss=-458.1680
# Epoch=093, loss=-456.4230
# Epoch=094, loss=-461.1962
# Epoch=095, loss=-462.5401
# Epoch=096, loss=-452.8681
# Epoch=097, loss=-457.6847
# Epoch=098, loss=-460.0463
# Epoch=099, loss=-459.2992

# %%
print("=== Evaluation ===")
graph = train_graph.remove_self_loop().add_self_loop()
adj = graph.adj().to_dense()

pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

embeds = model.get_embedding(graph, feat)

# loss_fn = F.binary_cross_entropy
loss_fn = F.binary_cross_entropy_with_logits
output_activation = nn.Sigmoid()
logreg = LogReg(embeds.shape[1], adj.shape[1])

logits_temp = logreg(embeds)
logits = output_activation(th.mm(logits_temp, logits_temp.t()))

val_roc, val_ap = get_scores(val_edges, val_edges_false, logits)
test_roc, test_ap = get_scores(test_edges, test_edges_false, logits)
print(test_roc, test_ap)
# Out:
# === Evaluation ===
# 0.9415646548819658 0.939592793268594

# %%
print("=== Evaluation ===")
graph = train_graph.remove_self_loop().add_self_loop()
adj = graph.adj().to_dense()

pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

embeds = model.get_embedding(graph, feat)

''' Linear Evaluation '''
logreg = LogReg(embeds.shape[1], adj.shape[1])
lr2 = 1e-2
wd2 = 1e-4
opt = th.optim.Adam(logreg.parameters(), lr=lr2, weight_decay=wd2)

loss_fn = F.binary_cross_entropy
# loss_fn = F.binary_cross_entropy_with_logits
output_activation = nn.Sigmoid()

#nn.CrossEntropyLoss()

best_val_roc = 0
eval_roc = 0
best_val_ap = 0
eval_ap = 0
    
for epoch in range(2000):
    logreg.train()
    opt.zero_grad()
    logits_temp = logreg(embeds)
    logits = output_activation(th.mm(logits_temp, logits_temp.t()))
    
    # pdb.set_trace()
    loss = loss_fn(logits, adj)
    # loss = norm * loss_fn(logits, adj, pos_weight = pos_weight)
    loss.backward()
    opt.step()

    logreg.eval()
    with th.no_grad():
        val_roc, val_ap = get_scores(val_edges, val_edges_false, logits)
        test_roc, test_ap = get_scores(test_edges, test_edges_false, logits)

        if val_roc >= best_val_roc:
            best_val_roc = val_roc
            if test_roc > eval_roc:
                eval_roc = test_roc
        
        if val_ap >= best_val_ap:
            best_val_ap = val_ap
            if test_ap > eval_ap:
                eval_ap = test_ap

    print('Epoch:{}, val_ap:{:.4f}, val_roc:{:4f}, test_ap:{:4f}, test_roc:{:4f}'.format(epoch, val_ap, val_roc, test_ap, test_roc))
    print('Linear evaluation AP:{:.4f}'.format(eval_ap))
    print('Linear evaluation ROC:{:.4f}'.format(eval_roc))
# Out:
# === Evaluation ===
# Epoch:0, val_ap:0.9381, val_roc:0.944172, test_ap:0.947187, test_roc:0.946114
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:1, val_ap:0.6854, val_roc:0.666862, test_ap:0.683328, test_roc:0.671102
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:2, val_ap:0.6605, val_roc:0.640585, test_ap:0.656147, test_roc:0.645925
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:3, val_ap:0.6651, val_roc:0.645943, test_ap:0.660982, test_roc:0.651300
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:4, val_ap:0.6878, val_roc:0.669858, test_ap:0.685841, test_roc:0.673870
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:5, val_ap:0.7611, val_roc:0.746173, test_ap:0.762262, test_roc:0.741208
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:6, val_ap:0.8961, val_roc:0.890364, test_ap:0.904065, test_roc:0.888968
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:7, val_ap:0.8593, val_roc:0.849569, test_ap:0.873355, test_roc:0.852789
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:8, val_ap:0.8589, val_roc:0.843491, test_ap:0.865596, test_roc:0.839632
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:9, val_ap:0.8239, val_roc:0.807276, test_ap:0.824215, test_roc:0.799402
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:10, val_ap:0.8298, val_roc:0.821265, test_ap:0.826361, test_roc:0.813940
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:11, val_ap:0.8611, val_roc:0.862964, test_ap:0.855907, test_roc:0.858853
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:12, val_ap:0.8515, val_roc:0.858700, test_ap:0.845325, test_roc:0.855231
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:13, val_ap:0.8010, val_roc:0.806887, test_ap:0.795218, test_roc:0.801603
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:14, val_ap:0.7620, val_roc:0.761462, test_ap:0.758978, test_roc:0.757106
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:15, val_ap:0.7560, val_roc:0.752845, test_ap:0.754250, test_roc:0.749252
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:16, val_ap:0.7844, val_roc:0.783973, test_ap:0.780464, test_roc:0.777776
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:17, val_ap:0.8450, val_roc:0.849501, test_ap:0.839820, test_roc:0.844092
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:18, val_ap:0.9012, val_roc:0.905624, test_ap:0.896755, test_roc:0.901011
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:19, val_ap:0.9108, val_roc:0.910607, test_ap:0.908850, test_roc:0.908609
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:20, val_ap:0.9021, val_roc:0.896399, test_ap:0.899752, test_roc:0.894029
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:21, val_ap:0.9037, val_roc:0.894347, test_ap:0.902283, test_roc:0.893039
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:22, val_ap:0.9166, val_roc:0.908432, test_ap:0.920263, test_roc:0.910550
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:23, val_ap:0.9281, val_roc:0.926126, test_ap:0.937139, test_roc:0.930451
# Linear evaluation AP:0.9472
# Linear evaluation ROC:0.9461
# Epoch:24, val_ap:0.9390, val_roc:0.943049, test_ap:0.950410, test_roc:0.947984
# Linear evaluation AP:0.9504
# Linear evaluation ROC:0.9461
# Epoch:25, val_ap:0.9451, val_roc:0.952133, test_ap:0.956263, test_roc:0.957966
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:26, val_ap:0.9380, val_roc:0.946063, test_ap:0.941317, test_roc:0.947122
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:27, val_ap:0.9214, val_roc:0.930537, test_ap:0.919324, test_roc:0.927963
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:28, val_ap:0.9067, val_roc:0.916458, test_ap:0.902373, test_roc:0.912712
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:29, val_ap:0.8966, val_roc:0.906661, test_ap:0.891711, test_roc:0.902861
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:30, val_ap:0.8936, val_roc:0.903103, test_ap:0.888819, test_roc:0.899956
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:31, val_ap:0.9014, val_roc:0.910031, test_ap:0.897240, test_roc:0.907602
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:32, val_ap:0.9201, val_roc:0.926882, test_ap:0.918004, test_roc:0.926198
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:33, val_ap:0.9386, val_roc:0.943654, test_ap:0.941257, test_roc:0.945529
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:34, val_ap:0.9402, val_roc:0.944352, test_ap:0.947011, test_roc:0.947240
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:35, val_ap:0.9270, val_roc:0.931422, test_ap:0.933407, test_roc:0.931478
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:36, val_ap:0.9146, val_roc:0.920206, test_ap:0.921984, test_roc:0.919989
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:37, val_ap:0.9165, val_roc:0.924246, test_ap:0.926976, test_roc:0.926660
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:38, val_ap:0.9311, val_roc:0.941245, test_ap:0.945319, test_roc:0.947562
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9580
# Epoch:39, val_ap:0.9443, val_roc:0.954873, test_ap:0.958452, test_roc:0.962491
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:40, val_ap:0.9453, val_roc:0.955457, test_ap:0.952843, test_roc:0.959405
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:41, val_ap:0.9378, val_roc:0.947164, test_ap:0.940397, test_roc:0.949147
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:42, val_ap:0.9341, val_roc:0.943204, test_ap:0.935275, test_roc:0.944683
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:43, val_ap:0.9372, val_roc:0.946160, test_ap:0.939759, test_roc:0.948340
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:44, val_ap:0.9430, val_roc:0.952094, test_ap:0.948061, test_roc:0.954970
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:45, val_ap:0.9440, val_roc:0.953311, test_ap:0.952738, test_roc:0.957980
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:46, val_ap:0.9384, val_roc:0.947395, test_ap:0.949524, test_roc:0.953702
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:47, val_ap:0.9301, val_roc:0.939761, test_ap:0.941944, test_roc:0.945930
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:48, val_ap:0.9253, val_roc:0.935977, test_ap:0.938029, test_roc:0.942462
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:49, val_ap:0.9285, val_roc:0.940157, test_ap:0.942362, test_roc:0.947360
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:50, val_ap:0.9351, val_roc:0.947258, test_ap:0.949651, test_roc:0.955129
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:51, val_ap:0.9399, val_roc:0.951957, test_ap:0.953408, test_roc:0.959376
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:52, val_ap:0.9415, val_roc:0.953444, test_ap:0.953901, test_roc:0.960201
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:53, val_ap:0.9416, val_roc:0.953584, test_ap:0.953567, test_roc:0.960088
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:54, val_ap:0.9408, val_roc:0.952807, test_ap:0.952942, test_roc:0.959555
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:55, val_ap:0.9397, val_roc:0.951514, test_ap:0.951961, test_roc:0.958555
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:56, val_ap:0.9382, val_roc:0.950056, test_ap:0.950823, test_roc:0.957406
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:57, val_ap:0.9367, val_roc:0.948831, test_ap:0.949643, test_roc:0.956300
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:58, val_ap:0.9360, val_roc:0.948252, test_ap:0.948866, test_roc:0.955773
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:59, val_ap:0.9354, val_roc:0.948111, test_ap:0.948444, test_roc:0.955597
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:60, val_ap:0.9347, val_roc:0.947658, test_ap:0.947875, test_roc:0.955263
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:61, val_ap:0.9330, val_roc:0.946351, test_ap:0.946647, test_roc:0.954282
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:62, val_ap:0.9307, val_roc:0.944406, test_ap:0.944952, test_roc:0.952822
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:63, val_ap:0.9285, val_roc:0.942257, test_ap:0.943021, test_roc:0.951130
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:64, val_ap:0.9270, val_roc:0.940874, test_ap:0.941894, test_roc:0.950093
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:65, val_ap:0.9271, val_roc:0.940993, test_ap:0.942037, test_roc:0.950326
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:66, val_ap:0.9290, val_roc:0.942757, test_ap:0.943433, test_roc:0.951753
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:67, val_ap:0.9310, val_roc:0.944946, test_ap:0.945169, test_roc:0.953485
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:68, val_ap:0.9328, val_roc:0.946675, test_ap:0.945988, test_roc:0.954468
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:69, val_ap:0.9329, val_roc:0.947082, test_ap:0.945941, test_roc:0.954598
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:70, val_ap:0.9314, val_roc:0.945901, test_ap:0.944890, test_roc:0.953780
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:71, val_ap:0.9285, val_roc:0.943463, test_ap:0.942940, test_roc:0.952040
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:72, val_ap:0.9254, val_roc:0.940193, test_ap:0.940199, test_roc:0.949559
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:73, val_ap:0.9218, val_roc:0.936870, test_ap:0.937395, test_roc:0.947012
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:74, val_ap:0.9199, val_roc:0.935138, test_ap:0.935768, test_roc:0.945626
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:75, val_ap:0.9204, val_roc:0.935556, test_ap:0.936059, test_roc:0.946021
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:76, val_ap:0.9224, val_roc:0.937421, test_ap:0.937521, test_roc:0.947444
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:77, val_ap:0.9246, val_roc:0.939502, test_ap:0.938994, test_roc:0.948920
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:78, val_ap:0.9256, val_roc:0.940593, test_ap:0.939506, test_roc:0.949537
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:79, val_ap:0.9255, val_roc:0.940550, test_ap:0.939140, test_roc:0.949325
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:80, val_ap:0.9237, val_roc:0.939142, test_ap:0.937969, test_roc:0.948465
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:81, val_ap:0.9213, val_roc:0.937061, test_ap:0.936167, test_roc:0.946940
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:82, val_ap:0.9193, val_roc:0.935351, test_ap:0.934465, test_roc:0.945537
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:83, val_ap:0.9182, val_roc:0.934224, test_ap:0.933121, test_roc:0.944501
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:84, val_ap:0.9177, val_roc:0.933961, test_ap:0.932536, test_roc:0.944133
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:85, val_ap:0.9176, val_roc:0.933957, test_ap:0.932383, test_roc:0.944085
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:86, val_ap:0.9178, val_roc:0.934062, test_ap:0.932291, test_roc:0.944048
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:87, val_ap:0.9175, val_roc:0.933864, test_ap:0.931749, test_roc:0.943625
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:88, val_ap:0.9166, val_roc:0.933107, test_ap:0.931074, test_roc:0.943076
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:89, val_ap:0.9156, val_roc:0.932301, test_ap:0.930182, test_roc:0.942386
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:90, val_ap:0.9148, val_roc:0.931635, test_ap:0.929499, test_roc:0.941879
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:91, val_ap:0.9143, val_roc:0.931350, test_ap:0.928848, test_roc:0.941600
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:92, val_ap:0.9143, val_roc:0.931516, test_ap:0.928542, test_roc:0.941531
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:93, val_ap:0.9142, val_roc:0.931721, test_ap:0.928267, test_roc:0.941400
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:94, val_ap:0.9140, val_roc:0.931538, test_ap:0.927666, test_roc:0.940927
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:95, val_ap:0.9131, val_roc:0.930691, test_ap:0.926754, test_roc:0.940070
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:96, val_ap:0.9116, val_roc:0.929395, test_ap:0.925548, test_roc:0.939031
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:97, val_ap:0.9101, val_roc:0.928160, test_ap:0.924345, test_roc:0.937975
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:98, val_ap:0.9089, val_roc:0.927148, test_ap:0.923426, test_roc:0.937212
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:99, val_ap:0.9084, val_roc:0.926846, test_ap:0.922929, test_roc:0.936880
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:100, val_ap:0.9083, val_roc:0.926994, test_ap:0.922816, test_roc:0.936956
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:101, val_ap:0.9083, val_roc:0.927372, test_ap:0.922691, test_roc:0.937080
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:102, val_ap:0.9082, val_roc:0.927458, test_ap:0.922340, test_roc:0.936939
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:103, val_ap:0.9075, val_roc:0.926846, test_ap:0.921575, test_roc:0.936376
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:104, val_ap:0.9062, val_roc:0.925701, test_ap:0.920534, test_roc:0.935452
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:105, val_ap:0.9046, val_roc:0.924333, test_ap:0.919341, test_roc:0.934394
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:106, val_ap:0.9030, val_roc:0.923058, test_ap:0.918195, test_roc:0.933468
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:107, val_ap:0.9020, val_roc:0.922288, test_ap:0.917413, test_roc:0.932824
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:108, val_ap:0.9015, val_roc:0.922025, test_ap:0.916944, test_roc:0.932504
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:109, val_ap:0.9012, val_roc:0.921931, test_ap:0.916588, test_roc:0.932328
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:110, val_ap:0.9008, val_roc:0.921841, test_ap:0.916198, test_roc:0.932081
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:111, val_ap:0.9001, val_roc:0.921402, test_ap:0.915607, test_roc:0.931612
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:112, val_ap:0.8993, val_roc:0.920714, test_ap:0.914672, test_roc:0.930955
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:113, val_ap:0.8980, val_roc:0.919749, test_ap:0.913784, test_roc:0.930229
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:114, val_ap:0.8970, val_roc:0.918842, test_ap:0.912953, test_roc:0.929550
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:115, val_ap:0.8963, val_roc:0.918266, test_ap:0.912174, test_roc:0.928952
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:116, val_ap:0.8957, val_roc:0.917754, test_ap:0.911441, test_roc:0.928446
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:117, val_ap:0.8952, val_roc:0.917427, test_ap:0.910898, test_roc:0.927962
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:118, val_ap:0.8941, val_roc:0.916833, test_ap:0.910153, test_roc:0.927403
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:119, val_ap:0.8931, val_roc:0.916084, test_ap:0.909352, test_roc:0.926791
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:120, val_ap:0.8920, val_roc:0.915310, test_ap:0.908478, test_roc:0.926134
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:121, val_ap:0.8909, val_roc:0.914496, test_ap:0.907659, test_roc:0.925522
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:122, val_ap:0.8901, val_roc:0.913844, test_ap:0.906846, test_roc:0.924938
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:123, val_ap:0.8892, val_roc:0.913311, test_ap:0.906201, test_roc:0.924437
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:124, val_ap:0.8886, val_roc:0.912836, test_ap:0.905442, test_roc:0.923924
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:125, val_ap:0.8879, val_roc:0.912245, test_ap:0.904641, test_roc:0.923347
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:126, val_ap:0.8870, val_roc:0.911514, test_ap:0.903865, test_roc:0.922690
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:127, val_ap:0.8859, val_roc:0.910636, test_ap:0.903004, test_roc:0.921958
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:128, val_ap:0.8850, val_roc:0.909826, test_ap:0.902113, test_roc:0.921208
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:129, val_ap:0.8842, val_roc:0.909188, test_ap:0.901225, test_roc:0.920563
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:130, val_ap:0.8834, val_roc:0.908656, test_ap:0.900428, test_roc:0.919991
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:131, val_ap:0.8827, val_roc:0.908187, test_ap:0.899707, test_roc:0.919481
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:132, val_ap:0.8819, val_roc:0.907669, test_ap:0.898997, test_roc:0.918949
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:133, val_ap:0.8810, val_roc:0.906974, test_ap:0.898155, test_roc:0.918336
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:134, val_ap:0.8801, val_roc:0.906279, test_ap:0.897306, test_roc:0.917718
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:135, val_ap:0.8792, val_roc:0.905433, test_ap:0.896335, test_roc:0.917011
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:136, val_ap:0.8782, val_roc:0.904598, test_ap:0.895309, test_roc:0.916251
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:137, val_ap:0.8773, val_roc:0.903896, test_ap:0.894368, test_roc:0.915634
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:138, val_ap:0.8764, val_roc:0.903204, test_ap:0.893500, test_roc:0.915042
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:139, val_ap:0.8757, val_roc:0.902700, test_ap:0.892755, test_roc:0.914465
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:140, val_ap:0.8749, val_roc:0.902124, test_ap:0.891979, test_roc:0.913851
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:141, val_ap:0.8741, val_roc:0.901436, test_ap:0.891206, test_roc:0.913238
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:142, val_ap:0.8731, val_roc:0.900684, test_ap:0.890327, test_roc:0.912489
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:143, val_ap:0.8720, val_roc:0.899802, test_ap:0.889480, test_roc:0.911816
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:144, val_ap:0.8712, val_roc:0.899175, test_ap:0.888661, test_roc:0.911113
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:145, val_ap:0.8703, val_roc:0.898451, test_ap:0.887868, test_roc:0.910472
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:146, val_ap:0.8694, val_roc:0.897807, test_ap:0.886896, test_roc:0.909777
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:147, val_ap:0.8682, val_roc:0.897065, test_ap:0.886098, test_roc:0.909154
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:148, val_ap:0.8674, val_roc:0.896446, test_ap:0.885290, test_roc:0.908531
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:149, val_ap:0.8665, val_roc:0.895686, test_ap:0.884296, test_roc:0.907789
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:150, val_ap:0.8655, val_roc:0.894966, test_ap:0.883394, test_roc:0.907139
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:151, val_ap:0.8647, val_roc:0.894303, test_ap:0.882543, test_roc:0.906464
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:152, val_ap:0.8639, val_roc:0.893652, test_ap:0.881715, test_roc:0.905813
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:153, val_ap:0.8630, val_roc:0.892978, test_ap:0.880928, test_roc:0.905179
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:154, val_ap:0.8620, val_roc:0.892211, test_ap:0.880036, test_roc:0.904514
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:155, val_ap:0.8611, val_roc:0.891495, test_ap:0.879300, test_roc:0.903862
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:156, val_ap:0.8601, val_roc:0.890721, test_ap:0.878349, test_roc:0.903188
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:157, val_ap:0.8591, val_roc:0.889983, test_ap:0.877483, test_roc:0.902503
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:158, val_ap:0.8583, val_roc:0.889295, test_ap:0.876713, test_roc:0.901876
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:159, val_ap:0.8573, val_roc:0.888582, test_ap:0.875942, test_roc:0.901248
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:160, val_ap:0.8565, val_roc:0.887923, test_ap:0.875208, test_roc:0.900635
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:161, val_ap:0.8557, val_roc:0.887351, test_ap:0.874344, test_roc:0.899906
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:162, val_ap:0.8548, val_roc:0.886648, test_ap:0.873499, test_roc:0.899208
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:163, val_ap:0.8537, val_roc:0.885878, test_ap:0.872631, test_roc:0.898495
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:164, val_ap:0.8530, val_roc:0.885266, test_ap:0.871835, test_roc:0.897804
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:165, val_ap:0.8521, val_roc:0.884517, test_ap:0.871066, test_roc:0.897167
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:166, val_ap:0.8513, val_roc:0.883800, test_ap:0.870325, test_roc:0.896501
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:167, val_ap:0.8504, val_roc:0.883037, test_ap:0.869511, test_roc:0.895832
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:168, val_ap:0.8496, val_roc:0.882364, test_ap:0.868615, test_roc:0.895099
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:169, val_ap:0.8485, val_roc:0.881611, test_ap:0.867699, test_roc:0.894329
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:170, val_ap:0.8479, val_roc:0.880945, test_ap:0.866946, test_roc:0.893640
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:171, val_ap:0.8469, val_roc:0.880265, test_ap:0.866003, test_roc:0.892933
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:172, val_ap:0.8462, val_roc:0.879674, test_ap:0.865113, test_roc:0.892250
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:173, val_ap:0.8454, val_roc:0.878947, test_ap:0.864348, test_roc:0.891605
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:174, val_ap:0.8446, val_roc:0.878324, test_ap:0.863529, test_roc:0.890903
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:175, val_ap:0.8438, val_roc:0.877586, test_ap:0.862729, test_roc:0.890188
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:176, val_ap:0.8430, val_roc:0.876876, test_ap:0.861866, test_roc:0.889480
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:177, val_ap:0.8421, val_roc:0.876106, test_ap:0.860976, test_roc:0.888774
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:178, val_ap:0.8413, val_roc:0.875397, test_ap:0.860104, test_roc:0.888071
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:179, val_ap:0.8404, val_roc:0.874698, test_ap:0.859216, test_roc:0.887370
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:180, val_ap:0.8397, val_roc:0.874039, test_ap:0.858403, test_roc:0.886733
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:181, val_ap:0.8390, val_roc:0.873431, test_ap:0.857637, test_roc:0.886060
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:182, val_ap:0.8384, val_roc:0.872901, test_ap:0.856831, test_roc:0.885363
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:183, val_ap:0.8378, val_roc:0.872304, test_ap:0.855881, test_roc:0.884628
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:184, val_ap:0.8369, val_roc:0.871609, test_ap:0.855150, test_roc:0.883945
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:185, val_ap:0.8360, val_roc:0.870867, test_ap:0.854418, test_roc:0.883287
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:186, val_ap:0.8353, val_roc:0.870266, test_ap:0.853638, test_roc:0.882623
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:187, val_ap:0.8346, val_roc:0.869625, test_ap:0.852777, test_roc:0.881912
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:188, val_ap:0.8339, val_roc:0.868883, test_ap:0.851971, test_roc:0.881231
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:189, val_ap:0.8331, val_roc:0.868238, test_ap:0.851126, test_roc:0.880522
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:190, val_ap:0.8322, val_roc:0.867450, test_ap:0.850272, test_roc:0.879834
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:191, val_ap:0.8314, val_roc:0.866834, test_ap:0.849456, test_roc:0.879166
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:192, val_ap:0.8305, val_roc:0.866074, test_ap:0.848697, test_roc:0.878551
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:193, val_ap:0.8298, val_roc:0.865452, test_ap:0.847866, test_roc:0.877820
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:194, val_ap:0.8290, val_roc:0.864753, test_ap:0.846993, test_roc:0.877120
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:195, val_ap:0.8282, val_roc:0.864058, test_ap:0.846196, test_roc:0.876443
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:196, val_ap:0.8274, val_roc:0.863399, test_ap:0.845454, test_roc:0.875764
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:197, val_ap:0.8267, val_roc:0.862766, test_ap:0.844615, test_roc:0.875102
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:198, val_ap:0.8259, val_roc:0.862135, test_ap:0.843853, test_roc:0.874414
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:199, val_ap:0.8250, val_roc:0.861444, test_ap:0.843074, test_roc:0.873738
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:200, val_ap:0.8243, val_roc:0.860854, test_ap:0.842263, test_roc:0.873081
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:201, val_ap:0.8234, val_roc:0.860198, test_ap:0.841471, test_roc:0.872409
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:202, val_ap:0.8226, val_roc:0.859507, test_ap:0.840649, test_roc:0.871675
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:203, val_ap:0.8217, val_roc:0.858819, test_ap:0.839932, test_roc:0.871040
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:204, val_ap:0.8211, val_roc:0.858258, test_ap:0.839103, test_roc:0.870339
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:205, val_ap:0.8205, val_roc:0.857642, test_ap:0.838269, test_roc:0.869653
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:206, val_ap:0.8197, val_roc:0.856986, test_ap:0.837548, test_roc:0.868976
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:207, val_ap:0.8188, val_roc:0.856364, test_ap:0.836770, test_roc:0.868289
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:208, val_ap:0.8181, val_roc:0.855805, test_ap:0.836039, test_roc:0.867661
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:209, val_ap:0.8173, val_roc:0.855168, test_ap:0.835212, test_roc:0.866974
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:210, val_ap:0.8166, val_roc:0.854603, test_ap:0.834418, test_roc:0.866299
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:211, val_ap:0.8156, val_roc:0.853825, test_ap:0.833678, test_roc:0.865670
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:212, val_ap:0.8148, val_roc:0.853137, test_ap:0.832870, test_roc:0.864995
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:213, val_ap:0.8141, val_roc:0.852594, test_ap:0.832062, test_roc:0.864334
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:214, val_ap:0.8132, val_roc:0.851881, test_ap:0.831304, test_roc:0.863692
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:215, val_ap:0.8125, val_roc:0.851337, test_ap:0.830563, test_roc:0.863057
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:216, val_ap:0.8117, val_roc:0.850603, test_ap:0.829883, test_roc:0.862427
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:217, val_ap:0.8109, val_roc:0.849926, test_ap:0.829076, test_roc:0.861755
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:218, val_ap:0.8102, val_roc:0.849296, test_ap:0.828337, test_roc:0.861127
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:219, val_ap:0.8095, val_roc:0.848644, test_ap:0.827596, test_roc:0.860476
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:220, val_ap:0.8089, val_roc:0.848089, test_ap:0.826840, test_roc:0.859887
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:221, val_ap:0.8081, val_roc:0.847488, test_ap:0.826029, test_roc:0.859261
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:222, val_ap:0.8075, val_roc:0.846973, test_ap:0.825201, test_roc:0.858567
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:223, val_ap:0.8068, val_roc:0.846357, test_ap:0.824413, test_roc:0.857925
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:224, val_ap:0.8061, val_roc:0.845850, test_ap:0.823698, test_roc:0.857288
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:225, val_ap:0.8055, val_roc:0.845328, test_ap:0.822902, test_roc:0.856626
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:226, val_ap:0.8047, val_roc:0.844773, test_ap:0.822143, test_roc:0.855971
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:227, val_ap:0.8039, val_roc:0.844143, test_ap:0.821338, test_roc:0.855292
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:228, val_ap:0.8033, val_roc:0.843632, test_ap:0.820634, test_roc:0.854668
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:229, val_ap:0.8027, val_roc:0.843063, test_ap:0.819935, test_roc:0.854054
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:230, val_ap:0.8018, val_roc:0.842386, test_ap:0.819219, test_roc:0.853419
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:231, val_ap:0.8012, val_roc:0.841813, test_ap:0.818451, test_roc:0.852717
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:232, val_ap:0.8006, val_roc:0.841266, test_ap:0.817647, test_roc:0.852062
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:233, val_ap:0.7999, val_roc:0.840647, test_ap:0.816971, test_roc:0.851444
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:234, val_ap:0.7993, val_roc:0.840028, test_ap:0.816273, test_roc:0.850808
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:235, val_ap:0.7985, val_roc:0.839408, test_ap:0.815525, test_roc:0.850184
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:236, val_ap:0.7976, val_roc:0.838814, test_ap:0.814795, test_roc:0.849500
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:237, val_ap:0.7970, val_roc:0.838274, test_ap:0.814056, test_roc:0.848879
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:238, val_ap:0.7963, val_roc:0.837647, test_ap:0.813250, test_roc:0.848221
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:239, val_ap:0.7956, val_roc:0.837093, test_ap:0.812425, test_roc:0.847603
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:240, val_ap:0.7949, val_roc:0.836556, test_ap:0.811703, test_roc:0.846934
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:241, val_ap:0.7944, val_roc:0.835995, test_ap:0.810936, test_roc:0.846255
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:242, val_ap:0.7937, val_roc:0.835426, test_ap:0.810309, test_roc:0.845689
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:243, val_ap:0.7930, val_roc:0.834864, test_ap:0.809552, test_roc:0.845047
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:244, val_ap:0.7924, val_roc:0.834328, test_ap:0.808845, test_roc:0.844448
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:245, val_ap:0.7916, val_roc:0.833737, test_ap:0.808229, test_roc:0.843809
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:246, val_ap:0.7909, val_roc:0.833111, test_ap:0.807496, test_roc:0.843190
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:247, val_ap:0.7903, val_roc:0.832545, test_ap:0.806820, test_roc:0.842589
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:248, val_ap:0.7897, val_roc:0.832056, test_ap:0.806141, test_roc:0.841970
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:249, val_ap:0.7889, val_roc:0.831433, test_ap:0.805477, test_roc:0.841362
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:250, val_ap:0.7882, val_roc:0.830821, test_ap:0.804753, test_roc:0.840734
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:251, val_ap:0.7875, val_roc:0.830227, test_ap:0.804073, test_roc:0.840106
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:252, val_ap:0.7867, val_roc:0.829665, test_ap:0.803450, test_roc:0.839556
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:253, val_ap:0.7862, val_roc:0.829168, test_ap:0.802731, test_roc:0.838960
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:254, val_ap:0.7856, val_roc:0.828628, test_ap:0.802014, test_roc:0.838315
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:255, val_ap:0.7850, val_roc:0.828124, test_ap:0.801313, test_roc:0.837703
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:256, val_ap:0.7844, val_roc:0.827620, test_ap:0.800703, test_roc:0.837102
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:257, val_ap:0.7838, val_roc:0.827094, test_ap:0.800084, test_roc:0.836527
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:258, val_ap:0.7831, val_roc:0.826547, test_ap:0.799391, test_roc:0.835911
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:259, val_ap:0.7825, val_roc:0.825996, test_ap:0.798673, test_roc:0.835302
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:260, val_ap:0.7819, val_roc:0.825459, test_ap:0.797876, test_roc:0.834662
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:261, val_ap:0.7813, val_roc:0.824937, test_ap:0.797252, test_roc:0.834108
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:262, val_ap:0.7805, val_roc:0.824426, test_ap:0.796641, test_roc:0.833535
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:263, val_ap:0.7798, val_roc:0.823828, test_ap:0.795987, test_roc:0.832926
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:264, val_ap:0.7791, val_roc:0.823234, test_ap:0.795356, test_roc:0.832332
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:265, val_ap:0.7786, val_roc:0.822809, test_ap:0.794715, test_roc:0.831748
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:266, val_ap:0.7780, val_roc:0.822276, test_ap:0.794077, test_roc:0.831175
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:267, val_ap:0.7774, val_roc:0.821715, test_ap:0.793487, test_roc:0.830594
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:268, val_ap:0.7770, val_roc:0.821283, test_ap:0.792887, test_roc:0.830015
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:269, val_ap:0.7764, val_roc:0.820750, test_ap:0.792294, test_roc:0.829493
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:270, val_ap:0.7759, val_roc:0.820274, test_ap:0.791652, test_roc:0.828908
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:271, val_ap:0.7753, val_roc:0.819734, test_ap:0.791001, test_roc:0.828355
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:272, val_ap:0.7747, val_roc:0.819198, test_ap:0.790395, test_roc:0.827782
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:273, val_ap:0.7741, val_roc:0.818687, test_ap:0.789809, test_roc:0.827212
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:274, val_ap:0.7735, val_roc:0.818172, test_ap:0.789101, test_roc:0.826600
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:275, val_ap:0.7729, val_roc:0.817675, test_ap:0.788539, test_roc:0.826058
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:276, val_ap:0.7722, val_roc:0.817016, test_ap:0.787887, test_roc:0.825489
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:277, val_ap:0.7716, val_roc:0.816425, test_ap:0.787317, test_roc:0.824945
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:278, val_ap:0.7711, val_roc:0.815964, test_ap:0.786698, test_roc:0.824378
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:279, val_ap:0.7705, val_roc:0.815478, test_ap:0.786058, test_roc:0.823804
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:280, val_ap:0.7700, val_roc:0.815000, test_ap:0.785422, test_roc:0.823252
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:281, val_ap:0.7694, val_roc:0.814528, test_ap:0.784832, test_roc:0.822683
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:282, val_ap:0.7687, val_roc:0.813963, test_ap:0.784228, test_roc:0.822155
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:283, val_ap:0.7682, val_roc:0.813437, test_ap:0.783657, test_roc:0.821595
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:284, val_ap:0.7678, val_roc:0.812987, test_ap:0.783077, test_roc:0.821043
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:285, val_ap:0.7671, val_roc:0.812443, test_ap:0.782394, test_roc:0.820494
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:286, val_ap:0.7666, val_roc:0.811971, test_ap:0.781840, test_roc:0.819967
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:287, val_ap:0.7660, val_roc:0.811431, test_ap:0.781194, test_roc:0.819408
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:288, val_ap:0.7655, val_roc:0.810862, test_ap:0.780594, test_roc:0.818853
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:289, val_ap:0.7650, val_roc:0.810434, test_ap:0.780020, test_roc:0.818319
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:290, val_ap:0.7645, val_roc:0.809955, test_ap:0.779461, test_roc:0.817753
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:291, val_ap:0.7640, val_roc:0.809509, test_ap:0.778985, test_roc:0.817275
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:292, val_ap:0.7636, val_roc:0.809134, test_ap:0.778394, test_roc:0.816689
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:293, val_ap:0.7630, val_roc:0.808608, test_ap:0.777807, test_roc:0.816134
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:294, val_ap:0.7623, val_roc:0.808072, test_ap:0.777285, test_roc:0.815621
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:295, val_ap:0.7617, val_roc:0.807553, test_ap:0.776644, test_roc:0.815012
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:296, val_ap:0.7612, val_roc:0.807096, test_ap:0.776112, test_roc:0.814488
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:297, val_ap:0.7608, val_roc:0.806628, test_ap:0.775495, test_roc:0.813914
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:298, val_ap:0.7604, val_roc:0.806182, test_ap:0.774989, test_roc:0.813425
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:299, val_ap:0.7599, val_roc:0.805670, test_ap:0.774486, test_roc:0.812921
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:300, val_ap:0.7594, val_roc:0.805292, test_ap:0.773835, test_roc:0.812339
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:301, val_ap:0.7590, val_roc:0.804846, test_ap:0.773316, test_roc:0.811848
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:302, val_ap:0.7584, val_roc:0.804363, test_ap:0.772794, test_roc:0.811326
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# Epoch:303, val_ap:0.7579, val_roc:0.803848, test_ap:0.772254, test_roc:0.810742
# Linear evaluation AP:0.9563
# Linear evaluation ROC:0.9625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e2ed9e8d09cf> in <module>
#      34     loss = loss_fn(logits, adj)
#      35     # loss = norm * loss_fn(logits, adj, pos_weight = pos_weight)
# ---> 36     loss.backward()
#      37     opt.step()
#      38
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145         retain_graph = create_graph
#     146
# --> 147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

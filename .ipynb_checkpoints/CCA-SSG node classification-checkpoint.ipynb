# %%
from model import CCA_SSG, LogReg
from aug import random_aug
from dataset import load

import numpy as np
import torch as th
import torch.nn as nn

import warnings

warnings.filterwarnings('ignore')

from sklearn.metrics import roc_auc_score, average_precision_score
from util import mask_test_edges_dgl
# Out:
# Using backend: pytorch

# %%
# parser.add_argument('--gpu', type=int, default=0, help='GPU index.')
# parser.add_argument('--use_mlp', action='store_true', default=False, help='Use MLP instead of GNN')

# %%
graph, feat, labels, num_class, train_idx, val_idx, test_idx = load('cora')
graph = graph.remove_self_loop().add_self_loop()
in_dim = feat.shape[1]

hid_dim = 512
out_dim = 512
n_layers = 2

model = CCA_SSG(in_dim, hid_dim, out_dim, n_layers, use_mlp=False)
lr1 = 1e-3 
wd1 = 0
optimizer = th.optim.Adam(model.parameters(), lr=lr1, weight_decay=wd1)

N = graph.number_of_nodes()

for epoch in range(100):
    model.train()
    optimizer.zero_grad()
    
    dfr = 0.2
    der = 0.2

    graph1, feat1 = random_aug(graph, feat, 0.2, 0.2)
    graph2, feat2 = random_aug(graph, feat, 0.2, 0.2)

    graph1 = graph1.add_self_loop()
    graph2 = graph2.add_self_loop()

    z1, z2 = model(graph1, feat1, graph2, feat2)

    c = th.mm(z1.T, z2)
    c1 = th.mm(z1.T, z1)
    c2 = th.mm(z2.T, z2)

    c = c / N
    c1 = c1 / N
    c2 = c2 / N

    loss_inv = -th.diagonal(c).sum()
    iden = th.tensor(np.eye(c.shape[0]))
    loss_dec1 = (iden - c1).pow(2).sum()
    loss_dec2 = (iden - c2).pow(2).sum()
    
    lambd = 1e-3
    
    loss = loss_inv + lambd * (loss_dec1 + loss_dec2)

    loss.backward()
    optimizer.step()

    print('Epoch={:03d}, loss={:.4f}'.format(epoch, loss.item()))
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# Epoch=000, loss=-333.1239
# Epoch=001, loss=-362.0690
# Epoch=002, loss=-338.8452
# Epoch=003, loss=-375.5197
# Epoch=004, loss=-378.3668
# Epoch=005, loss=-393.6665
# Epoch=006, loss=-404.0918
# Epoch=007, loss=-407.9352
# Epoch=008, loss=-392.5743
# Epoch=009, loss=-410.6282
# Epoch=010, loss=-418.6497
# Epoch=011, loss=-420.0819
# Epoch=012, loss=-419.2513
# Epoch=013, loss=-417.7541
# Epoch=014, loss=-417.9207
# Epoch=015, loss=-423.5932
# Epoch=016, loss=-425.0707
# Epoch=017, loss=-419.4870
# Epoch=018, loss=-426.1390
# Epoch=019, loss=-417.1960
# Epoch=020, loss=-434.0430
# Epoch=021, loss=-433.9163
# Epoch=022, loss=-433.7112
# Epoch=023, loss=-431.5808
# Epoch=024, loss=-426.4957
# Epoch=025, loss=-438.7745
# Epoch=026, loss=-434.8502
# Epoch=027, loss=-432.5161
# Epoch=028, loss=-441.5172
# Epoch=029, loss=-445.0157
# Epoch=030, loss=-447.1457
# Epoch=031, loss=-440.6973
# Epoch=032, loss=-438.5877
# Epoch=033, loss=-443.1572
# Epoch=034, loss=-447.5959
# Epoch=035, loss=-437.2012
# Epoch=036, loss=-438.0320
# Epoch=037, loss=-446.6216
# Epoch=038, loss=-438.0755
# Epoch=039, loss=-447.9952
# Epoch=040, loss=-441.8189
# Epoch=041, loss=-453.5888
# Epoch=042, loss=-446.1536
# Epoch=043, loss=-444.7232
# Epoch=044, loss=-447.4526
# Epoch=045, loss=-448.5589
# Epoch=046, loss=-452.0005
# Epoch=047, loss=-454.1272
# Epoch=048, loss=-451.8722
# Epoch=049, loss=-446.6441
# Epoch=050, loss=-449.0992
# Epoch=051, loss=-453.0149
# Epoch=052, loss=-448.9967
# Epoch=053, loss=-452.4148
# Epoch=054, loss=-451.1354
# Epoch=055, loss=-454.1574
# Epoch=056, loss=-449.0347
# Epoch=057, loss=-454.6436
# Epoch=058, loss=-449.5368
# Epoch=059, loss=-449.8877
# Epoch=060, loss=-454.3640
# Epoch=061, loss=-453.4364
# Epoch=062, loss=-453.9601
# Epoch=063, loss=-456.0697
# Epoch=064, loss=-456.8285
# Epoch=065, loss=-451.9787
# Epoch=066, loss=-454.6359
# Epoch=067, loss=-456.2674
# Epoch=068, loss=-456.7712
# Epoch=069, loss=-461.4951
# Epoch=070, loss=-454.4196
# Epoch=071, loss=-453.8091
# Epoch=072, loss=-455.0063
# Epoch=073, loss=-457.4957
# Epoch=074, loss=-455.2134
# Epoch=075, loss=-451.1474
# Epoch=076, loss=-459.0581
# Epoch=077, loss=-453.2643
# Epoch=078, loss=-456.9924
# Epoch=079, loss=-454.2276
# Epoch=080, loss=-459.7010
# Epoch=081, loss=-455.3427
# Epoch=082, loss=-455.4674
# Epoch=083, loss=-455.5551
# Epoch=084, loss=-458.5191
# Epoch=085, loss=-453.5740
# Epoch=086, loss=-459.2532
# Epoch=087, loss=-456.3149
# Epoch=088, loss=-460.5850
# Epoch=089, loss=-457.2502
# Epoch=090, loss=-459.3455
# Epoch=091, loss=-457.6821
# Epoch=092, loss=-457.9389
# Epoch=093, loss=-462.5522
# Epoch=094, loss=-459.0615
# Epoch=095, loss=-459.4470
# Epoch=096, loss=-461.0837
# Epoch=097, loss=-460.3516
# Epoch=098, loss=-458.4944
# Epoch=099, loss=-459.4499

# %%
print("=== Evaluation ===")
graph = graph.remove_self_loop().add_self_loop()

embeds = model.get_embedding(graph, feat)

train_embs = embeds[train_idx]
val_embs = embeds[val_idx]
test_embs = embeds[test_idx]

label = labels

train_labels = label[train_idx]
val_labels = label[val_idx]
test_labels = label[test_idx]

train_feat = feat[train_idx]
val_feat = feat[val_idx]
test_feat = feat[test_idx] 

''' Linear Evaluation '''
logreg = LogReg(train_embs.shape[1], num_class)
lr2 = 1e-2
wd2 = 1e-4
opt = th.optim.Adam(logreg.parameters(), lr=lr2, weight_decay=wd2)

loss_fn = nn.CrossEntropyLoss()

best_val_acc = 0
eval_acc = 0
    
for epoch in range(2000):
    logreg.train()
    opt.zero_grad()
    logits = logreg(train_embs)
    preds = th.argmax(logits, dim=1)
    train_acc = th.sum(preds == train_labels).float() / train_labels.shape[0]
    loss = loss_fn(logits, train_labels)
    loss.backward()
    opt.step()

    logreg.eval()
    with th.no_grad():
        val_logits = logreg(val_embs)
        test_logits = logreg(test_embs)

        val_preds = th.argmax(val_logits, dim=1)
        test_preds = th.argmax(test_logits, dim=1)

        val_acc = th.sum(val_preds == val_labels).float() / val_labels.shape[0]
        test_acc = th.sum(test_preds == test_labels).float() / test_labels.shape[0]

        if val_acc >= best_val_acc:
            best_val_acc = val_acc
            if test_acc > eval_acc:
                eval_acc = test_acc

    print('Epoch:{}, train_acc:{:.4f}, val_acc:{:4f}, test_acc:{:4f}'.format(epoch, train_acc, val_acc, test_acc))
    print('Linear evaluation accuracy:{:.4f}'.format(eval_acc))
# Out:
# === Evaluation ===
# Epoch:0, train_acc:0.1071, val_acc:0.308000, test_acc:0.326000
# Linear evaluation accuracy:0.3260
# Epoch:1, train_acc:0.5143, val_acc:0.648000, test_acc:0.663000
# Linear evaluation accuracy:0.6630
# Epoch:2, train_acc:0.8071, val_acc:0.736000, test_acc:0.759000
# Linear evaluation accuracy:0.7590
# Epoch:3, train_acc:0.8643, val_acc:0.756000, test_acc:0.780000
# Linear evaluation accuracy:0.7800
# Epoch:4, train_acc:0.8786, val_acc:0.778000, test_acc:0.789000
# Linear evaluation accuracy:0.7890
# Epoch:5, train_acc:0.8857, val_acc:0.782000, test_acc:0.791000
# Linear evaluation accuracy:0.7910
# Epoch:6, train_acc:0.9000, val_acc:0.786000, test_acc:0.799000
# Linear evaluation accuracy:0.7990
# Epoch:7, train_acc:0.8929, val_acc:0.790000, test_acc:0.808000
# Linear evaluation accuracy:0.8080
# Epoch:8, train_acc:0.8929, val_acc:0.788000, test_acc:0.812000
# Linear evaluation accuracy:0.8080
# Epoch:9, train_acc:0.8857, val_acc:0.788000, test_acc:0.815000
# Linear evaluation accuracy:0.8080
# Epoch:10, train_acc:0.8786, val_acc:0.780000, test_acc:0.815000
# Linear evaluation accuracy:0.8080
# Epoch:11, train_acc:0.8786, val_acc:0.782000, test_acc:0.812000
# Linear evaluation accuracy:0.8080
# Epoch:12, train_acc:0.8786, val_acc:0.780000, test_acc:0.811000
# Linear evaluation accuracy:0.8080
# Epoch:13, train_acc:0.8786, val_acc:0.776000, test_acc:0.809000
# Linear evaluation accuracy:0.8080
# Epoch:14, train_acc:0.8786, val_acc:0.778000, test_acc:0.810000
# Linear evaluation accuracy:0.8080
# Epoch:15, train_acc:0.8786, val_acc:0.780000, test_acc:0.814000
# Linear evaluation accuracy:0.8080
# Epoch:16, train_acc:0.8786, val_acc:0.780000, test_acc:0.815000
# Linear evaluation accuracy:0.8080
# Epoch:17, train_acc:0.8786, val_acc:0.778000, test_acc:0.814000
# Linear evaluation accuracy:0.8080
# Epoch:18, train_acc:0.8786, val_acc:0.782000, test_acc:0.814000
# Linear evaluation accuracy:0.8080
# Epoch:19, train_acc:0.8786, val_acc:0.784000, test_acc:0.815000
# Linear evaluation accuracy:0.8080
# Epoch:20, train_acc:0.8786, val_acc:0.786000, test_acc:0.813000
# Linear evaluation accuracy:0.8080
# Epoch:21, train_acc:0.8786, val_acc:0.788000, test_acc:0.817000
# Linear evaluation accuracy:0.8080
# Epoch:22, train_acc:0.8786, val_acc:0.788000, test_acc:0.817000
# Linear evaluation accuracy:0.8080
# Epoch:23, train_acc:0.8786, val_acc:0.788000, test_acc:0.817000
# Linear evaluation accuracy:0.8080
# Epoch:24, train_acc:0.8786, val_acc:0.790000, test_acc:0.817000
# Linear evaluation accuracy:0.8170
# Epoch:25, train_acc:0.8786, val_acc:0.786000, test_acc:0.817000
# Linear evaluation accuracy:0.8170
# Epoch:26, train_acc:0.8786, val_acc:0.792000, test_acc:0.819000
# Linear evaluation accuracy:0.8190
# Epoch:27, train_acc:0.8786, val_acc:0.792000, test_acc:0.821000
# Linear evaluation accuracy:0.8210
# Epoch:28, train_acc:0.8786, val_acc:0.792000, test_acc:0.821000
# Linear evaluation accuracy:0.8210
# Epoch:29, train_acc:0.8786, val_acc:0.792000, test_acc:0.823000
# Linear evaluation accuracy:0.8230
# Epoch:30, train_acc:0.8786, val_acc:0.792000, test_acc:0.823000
# Linear evaluation accuracy:0.8230
# Epoch:31, train_acc:0.8786, val_acc:0.792000, test_acc:0.823000
# Linear evaluation accuracy:0.8230
# Epoch:32, train_acc:0.8786, val_acc:0.792000, test_acc:0.825000
# Linear evaluation accuracy:0.8250
# Epoch:33, train_acc:0.8786, val_acc:0.792000, test_acc:0.825000
# Linear evaluation accuracy:0.8250
# Epoch:34, train_acc:0.8857, val_acc:0.792000, test_acc:0.825000
# Linear evaluation accuracy:0.8250
# Epoch:35, train_acc:0.8857, val_acc:0.794000, test_acc:0.826000
# Linear evaluation accuracy:0.8260
# Epoch:36, train_acc:0.8857, val_acc:0.796000, test_acc:0.828000
# Linear evaluation accuracy:0.8280
# Epoch:37, train_acc:0.8857, val_acc:0.796000, test_acc:0.829000
# Linear evaluation accuracy:0.8290
# Epoch:38, train_acc:0.8857, val_acc:0.794000, test_acc:0.832000
# Linear evaluation accuracy:0.8290
# Epoch:39, train_acc:0.8857, val_acc:0.794000, test_acc:0.834000
# Linear evaluation accuracy:0.8290
# Epoch:40, train_acc:0.8857, val_acc:0.796000, test_acc:0.833000
# Linear evaluation accuracy:0.8330
# Epoch:41, train_acc:0.8857, val_acc:0.798000, test_acc:0.833000
# Linear evaluation accuracy:0.8330
# Epoch:42, train_acc:0.8857, val_acc:0.798000, test_acc:0.833000
# Linear evaluation accuracy:0.8330
# Epoch:43, train_acc:0.8929, val_acc:0.798000, test_acc:0.835000
# Linear evaluation accuracy:0.8350
# Epoch:44, train_acc:0.8929, val_acc:0.800000, test_acc:0.837000
# Linear evaluation accuracy:0.8370
# Epoch:45, train_acc:0.8929, val_acc:0.800000, test_acc:0.837000
# Linear evaluation accuracy:0.8370
# Epoch:46, train_acc:0.8929, val_acc:0.800000, test_acc:0.837000
# Linear evaluation accuracy:0.8370
# Epoch:47, train_acc:0.8929, val_acc:0.800000, test_acc:0.836000
# Linear evaluation accuracy:0.8370
# Epoch:48, train_acc:0.9000, val_acc:0.798000, test_acc:0.836000
# Linear evaluation accuracy:0.8370
# Epoch:49, train_acc:0.9000, val_acc:0.798000, test_acc:0.836000
# Linear evaluation accuracy:0.8370
# Epoch:50, train_acc:0.9000, val_acc:0.798000, test_acc:0.836000
# Linear evaluation accuracy:0.8370
# Epoch:51, train_acc:0.9071, val_acc:0.798000, test_acc:0.836000
# Linear evaluation accuracy:0.8370
# Epoch:52, train_acc:0.9071, val_acc:0.798000, test_acc:0.836000
# Linear evaluation accuracy:0.8370
# Epoch:53, train_acc:0.9071, val_acc:0.798000, test_acc:0.838000
# Linear evaluation accuracy:0.8370
# Epoch:54, train_acc:0.9071, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8380
# Epoch:55, train_acc:0.9071, val_acc:0.800000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:56, train_acc:0.9071, val_acc:0.800000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:57, train_acc:0.9071, val_acc:0.800000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:58, train_acc:0.9071, val_acc:0.800000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:59, train_acc:0.9143, val_acc:0.804000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:60, train_acc:0.9143, val_acc:0.804000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:61, train_acc:0.9143, val_acc:0.804000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:62, train_acc:0.9143, val_acc:0.804000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:63, train_acc:0.9143, val_acc:0.804000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:64, train_acc:0.9143, val_acc:0.804000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:65, train_acc:0.9143, val_acc:0.802000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:66, train_acc:0.9143, val_acc:0.802000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:67, train_acc:0.9143, val_acc:0.802000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:68, train_acc:0.9143, val_acc:0.802000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:69, train_acc:0.9143, val_acc:0.802000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:70, train_acc:0.9143, val_acc:0.802000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:71, train_acc:0.9143, val_acc:0.806000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:72, train_acc:0.9143, val_acc:0.806000, test_acc:0.838000
# Linear evaluation accuracy:0.8380
# Epoch:73, train_acc:0.9143, val_acc:0.808000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:74, train_acc:0.9143, val_acc:0.808000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:75, train_acc:0.9143, val_acc:0.808000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:76, train_acc:0.9143, val_acc:0.808000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:77, train_acc:0.9143, val_acc:0.808000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:78, train_acc:0.9143, val_acc:0.808000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:79, train_acc:0.9143, val_acc:0.808000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:80, train_acc:0.9143, val_acc:0.808000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:81, train_acc:0.9143, val_acc:0.808000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:82, train_acc:0.9143, val_acc:0.810000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:83, train_acc:0.9143, val_acc:0.810000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:84, train_acc:0.9143, val_acc:0.808000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:85, train_acc:0.9143, val_acc:0.808000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:86, train_acc:0.9143, val_acc:0.808000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:87, train_acc:0.9143, val_acc:0.808000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:88, train_acc:0.9143, val_acc:0.806000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:89, train_acc:0.9143, val_acc:0.806000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:90, train_acc:0.9143, val_acc:0.808000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:91, train_acc:0.9143, val_acc:0.808000, test_acc:0.835000
# Linear evaluation accuracy:0.8380
# Epoch:92, train_acc:0.9143, val_acc:0.806000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:93, train_acc:0.9143, val_acc:0.806000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:94, train_acc:0.9143, val_acc:0.806000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:95, train_acc:0.9143, val_acc:0.806000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:96, train_acc:0.9143, val_acc:0.806000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:97, train_acc:0.9143, val_acc:0.806000, test_acc:0.836000
# Linear evaluation accuracy:0.8380
# Epoch:98, train_acc:0.9143, val_acc:0.806000, test_acc:0.838000
# Linear evaluation accuracy:0.8380
# Epoch:99, train_acc:0.9143, val_acc:0.806000, test_acc:0.838000
# Linear evaluation accuracy:0.8380
# Epoch:100, train_acc:0.9143, val_acc:0.806000, test_acc:0.838000
# Linear evaluation accuracy:0.8380
# Epoch:101, train_acc:0.9143, val_acc:0.806000, test_acc:0.838000
# Linear evaluation accuracy:0.8380
# Epoch:102, train_acc:0.9143, val_acc:0.804000, test_acc:0.838000
# Linear evaluation accuracy:0.8380
# Epoch:103, train_acc:0.9143, val_acc:0.804000, test_acc:0.838000
# Linear evaluation accuracy:0.8380
# Epoch:104, train_acc:0.9143, val_acc:0.806000, test_acc:0.837000
# Linear evaluation accuracy:0.8380
# Epoch:105, train_acc:0.9143, val_acc:0.806000, test_acc:0.839000
# Linear evaluation accuracy:0.8380
# Epoch:106, train_acc:0.9143, val_acc:0.806000, test_acc:0.839000
# Linear evaluation accuracy:0.8380
# Epoch:107, train_acc:0.9143, val_acc:0.806000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:108, train_acc:0.9143, val_acc:0.806000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:109, train_acc:0.9143, val_acc:0.806000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:110, train_acc:0.9143, val_acc:0.806000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:111, train_acc:0.9143, val_acc:0.806000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:112, train_acc:0.9143, val_acc:0.806000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:113, train_acc:0.9143, val_acc:0.806000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:114, train_acc:0.9143, val_acc:0.806000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:115, train_acc:0.9143, val_acc:0.804000, test_acc:0.839000
# Linear evaluation accuracy:0.8380
# Epoch:116, train_acc:0.9143, val_acc:0.804000, test_acc:0.839000
# Linear evaluation accuracy:0.8380
# Epoch:117, train_acc:0.9214, val_acc:0.808000, test_acc:0.839000
# Linear evaluation accuracy:0.8380
# Epoch:118, train_acc:0.9214, val_acc:0.808000, test_acc:0.839000
# Linear evaluation accuracy:0.8380
# Epoch:119, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:120, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8380
# Epoch:121, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8400
# Epoch:122, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8400
# Epoch:123, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:124, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:125, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:126, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:127, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:128, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:129, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:130, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:131, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:132, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:133, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:134, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:135, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:136, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:137, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:138, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:139, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:140, train_acc:0.9214, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:141, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:142, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:143, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:144, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:145, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:146, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:147, train_acc:0.9214, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:148, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:149, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:150, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:151, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:152, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:153, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:154, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:155, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:156, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:157, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:158, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:159, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:160, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:161, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:162, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:163, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:164, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:165, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:166, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:167, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:168, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:169, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:170, train_acc:0.9214, val_acc:0.810000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:171, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:172, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:173, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:174, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:175, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:176, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:177, train_acc:0.9214, val_acc:0.810000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:178, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:179, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:180, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:181, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:182, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:183, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:184, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:185, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:186, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:187, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:188, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:189, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:190, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:191, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:192, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:193, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:194, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:195, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:196, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:197, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:198, train_acc:0.9214, val_acc:0.810000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:199, train_acc:0.9214, val_acc:0.810000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:200, train_acc:0.9214, val_acc:0.810000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:201, train_acc:0.9214, val_acc:0.810000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:202, train_acc:0.9214, val_acc:0.810000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:203, train_acc:0.9214, val_acc:0.810000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:204, train_acc:0.9214, val_acc:0.810000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:205, train_acc:0.9214, val_acc:0.810000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:206, train_acc:0.9214, val_acc:0.808000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:207, train_acc:0.9214, val_acc:0.808000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:208, train_acc:0.9214, val_acc:0.808000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:209, train_acc:0.9214, val_acc:0.808000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:210, train_acc:0.9214, val_acc:0.808000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:211, train_acc:0.9214, val_acc:0.808000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:212, train_acc:0.9286, val_acc:0.808000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:213, train_acc:0.9286, val_acc:0.808000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:214, train_acc:0.9286, val_acc:0.808000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:215, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:216, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:217, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:218, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:219, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:220, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:221, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:222, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:223, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:224, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:225, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:226, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:227, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:228, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:229, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:230, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:231, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:232, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:233, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:234, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:235, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:236, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:237, train_acc:0.9286, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:238, train_acc:0.9357, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:239, train_acc:0.9357, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:240, train_acc:0.9429, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:241, train_acc:0.9429, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:242, train_acc:0.9429, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:243, train_acc:0.9429, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:244, train_acc:0.9429, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:245, train_acc:0.9429, val_acc:0.808000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:246, train_acc:0.9429, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:247, train_acc:0.9429, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:248, train_acc:0.9429, val_acc:0.808000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:249, train_acc:0.9429, val_acc:0.806000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:250, train_acc:0.9429, val_acc:0.806000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:251, train_acc:0.9429, val_acc:0.806000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:252, train_acc:0.9429, val_acc:0.806000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:253, train_acc:0.9429, val_acc:0.804000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:254, train_acc:0.9429, val_acc:0.804000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:255, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:256, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:257, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:258, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:259, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:260, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:261, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:262, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:263, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:264, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:265, train_acc:0.9429, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:266, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:267, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:268, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:269, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:270, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:271, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:272, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:273, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:274, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:275, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:276, train_acc:0.9500, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:277, train_acc:0.9571, val_acc:0.798000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:278, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:279, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:280, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:281, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:282, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:283, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:284, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:285, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:286, train_acc:0.9571, val_acc:0.798000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:287, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:288, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:289, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:290, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:291, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:292, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:293, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:294, train_acc:0.9571, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:295, train_acc:0.9571, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:296, train_acc:0.9571, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:297, train_acc:0.9571, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:298, train_acc:0.9571, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:299, train_acc:0.9571, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:300, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:301, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:302, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:303, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:304, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:305, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:306, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:307, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:308, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:309, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:310, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:311, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:312, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:313, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:314, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:315, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:316, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:317, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:318, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:319, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:320, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:321, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:322, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:323, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:324, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:325, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:326, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:327, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:328, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:329, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:330, train_acc:0.9571, val_acc:0.802000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:331, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:332, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:333, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:334, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:335, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:336, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:337, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:338, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:339, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:340, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:341, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:342, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:343, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:344, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:345, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:346, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:347, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:348, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:349, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:350, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:351, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:352, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:353, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:354, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:355, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:356, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:357, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:358, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:359, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:360, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:361, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:362, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:363, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:364, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:365, train_acc:0.9571, val_acc:0.800000, test_acc:0.839000
# Linear evaluation accuracy:0.8410
# Epoch:366, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:367, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:368, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:369, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:370, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:371, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:372, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:373, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:374, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:375, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:376, train_acc:0.9571, val_acc:0.800000, test_acc:0.838000
# Linear evaluation accuracy:0.8410
# Epoch:377, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:378, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:379, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:380, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:381, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:382, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:383, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:384, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:385, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:386, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:387, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:388, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:389, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:390, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:391, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:392, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:393, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:394, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:395, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:396, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:397, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:398, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:399, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:400, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:401, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:402, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:403, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:404, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:405, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:406, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:407, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:408, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:409, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:410, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:411, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:412, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:413, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:414, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:415, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:416, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:417, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:418, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:419, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:420, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:421, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:422, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:423, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:424, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:425, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:426, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:427, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:428, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:429, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:430, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:431, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:432, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:433, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:434, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:435, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:436, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:437, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:438, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:439, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:440, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:441, train_acc:0.9571, val_acc:0.800000, test_acc:0.840000
# Linear evaluation accuracy:0.8410
# Epoch:442, train_acc:0.9571, val_acc:0.800000, test_acc:0.841000
# Linear evaluation accuracy:0.8410
# Epoch:443, train_acc:0.9571, val_acc:0.800000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:444, train_acc:0.9571, val_acc:0.800000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:445, train_acc:0.9571, val_acc:0.800000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:446, train_acc:0.9571, val_acc:0.800000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:447, train_acc:0.9571, val_acc:0.800000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:448, train_acc:0.9571, val_acc:0.800000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:449, train_acc:0.9571, val_acc:0.798000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:450, train_acc:0.9571, val_acc:0.798000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:451, train_acc:0.9571, val_acc:0.798000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:452, train_acc:0.9571, val_acc:0.798000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:453, train_acc:0.9571, val_acc:0.798000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:454, train_acc:0.9571, val_acc:0.798000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:455, train_acc:0.9571, val_acc:0.798000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:456, train_acc:0.9571, val_acc:0.798000, test_acc:0.842000
# Linear evaluation accuracy:0.8410
# Epoch:457, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:458, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:459, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:460, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:461, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:462, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:463, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:464, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:465, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:466, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:467, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:468, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:469, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:470, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:471, train_acc:0.9571, val_acc:0.798000, test_acc:0.843000
# Linear evaluation accuracy:0.8410
# Epoch:472, train_acc:0.9571, val_acc:0.798000, test_acc:0.844000
# Linear evaluation accuracy:0.8410
# Epoch:473, train_acc:0.9571, val_acc:0.796000, test_acc:0.844000
# Linear evaluation accuracy:0.8410
# Epoch:474, train_acc:0.9571, val_acc:0.796000, test_acc:0.844000
# Linear evaluation accuracy:0.8410
# Epoch:475, train_acc:0.9571, val_acc:0.796000, test_acc:0.844000
# Linear evaluation accuracy:0.8410
# Epoch:476, train_acc:0.9571, val_acc:0.796000, test_acc:0.844000
# Linear evaluation accuracy:0.8410
# Epoch:477, train_acc:0.9571, val_acc:0.796000, test_acc:0.844000
# Linear evaluation accuracy:0.8410
# Epoch:478, train_acc:0.9571, val_acc:0.796000, test_acc:0.845000
# Linear evaluation accuracy:0.8410
# Epoch:479, train_acc:0.9571, val_acc:0.796000, test_acc:0.845000
# Linear evaluation accuracy:0.8410
# Epoch:480, train_acc:0.9571, val_acc:0.796000, test_acc:0.845000
# Linear evaluation accuracy:0.8410
# Epoch:481, train_acc:0.9571, val_acc:0.796000, test_acc:0.845000
# Linear evaluation accuracy:0.8410
# Epoch:482, train_acc:0.9571, val_acc:0.796000, test_acc:0.845000
# Linear evaluation accuracy:0.8410
# Epoch:483, train_acc:0.9571, val_acc:0.796000, test_acc:0.845000
# Linear evaluation accuracy:0.8410
# Epoch:484, train_acc:0.9571, val_acc:0.796000, test_acc:0.845000
# Linear evaluation accuracy:0.8410
# Epoch:485, train_acc:0.9571, val_acc:0.796000, test_acc:0.845000
# ...
# Epoch:1840, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1841, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1842, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1843, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1844, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1845, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1846, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1847, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1848, train_acc:0.9571, val_acc:0.796000, test_acc:0.849000
# Linear evaluation accuracy:0.8410
# Epoch:1849, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1850, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1851, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1852, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1853, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1854, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1855, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1856, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1857, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1858, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1859, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1860, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1861, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1862, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1863, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1864, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1865, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1866, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1867, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1868, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1869, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1870, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1871, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1872, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1873, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1874, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1875, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1876, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1877, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1878, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1879, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1880, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1881, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1882, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1883, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1884, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1885, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1886, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1887, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1888, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1889, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1890, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1891, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1892, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1893, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1894, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1895, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1896, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1897, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1898, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1899, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1900, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1901, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1902, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1903, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1904, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1905, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1906, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1907, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1908, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1909, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1910, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1911, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1912, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1913, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1914, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1915, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1916, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1917, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1918, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1919, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1920, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1921, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1922, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1923, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1924, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1925, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1926, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1927, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1928, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1929, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1930, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1931, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1932, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1933, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1934, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1935, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1936, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1937, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1938, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1939, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1940, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1941, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1942, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1943, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1944, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1945, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1946, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1947, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1948, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1949, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1950, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1951, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1952, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1953, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1954, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1955, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1956, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1957, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1958, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1959, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1960, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1961, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1962, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1963, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1964, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1965, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1966, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1967, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1968, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1969, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1970, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1971, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1972, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1973, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1974, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1975, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1976, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1977, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1978, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1979, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1980, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1981, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1982, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1983, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1984, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1985, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1986, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1987, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1988, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1989, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1990, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1991, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1992, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1993, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1994, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1995, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1996, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1997, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1998, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410
# Epoch:1999, train_acc:0.9571, val_acc:0.796000, test_acc:0.848000
# Linear evaluation accuracy:0.8410

# %%
from model import CCA_SSG, LogReg
from model2 import TOCCA_link
from aug import random_aug
from dataset import load

import numpy as np
import torch as th
import torch.nn as nn

import warnings

warnings.filterwarnings('ignore')

from sklearn.metrics import roc_auc_score, average_precision_score
from util import mask_test_edges_dgl
import dgl
import torch.nn.functional as F
import pdb
# Out:
# Using backend: pytorch

# %%
# parser.add_argument('--gpu', type=int, default=0, help='GPU index.')
# parser.add_argument('--use_mlp', action='store_true', default=False, help='Use MLP instead of GNN')

# %%
def get_scores(edges_pos, edges_neg, adj_rec):
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    adj_rec = adj_rec.cpu()
    # Predict on test set of edges
    preds = []
    for e in edges_pos:
        preds.append(sigmoid(adj_rec[e[0], e[1]].item()))

    preds_neg = []
    for e in edges_neg:
        preds_neg.append(sigmoid(adj_rec[e[0], e[1]].data))

    preds_all = np.hstack([preds, preds_neg])
    labels_all = np.hstack([np.ones(len(preds)), np.zeros(len(preds_neg))])
    roc_score = roc_auc_score(labels_all, preds_all)
    ap_score = average_precision_score(labels_all, preds_all)

    return roc_score, ap_score

# %%
graph, feat, labels, num_class, train_idx, val_idx, test_idx = load('cora')
adj_orig = graph.adj().to_dense()
train_edge_idx, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_dgl(graph, adj_orig)

# create train graph
train_edge_idx = th.tensor(train_edge_idx)
train_graph = dgl.edge_subgraph(graph, train_edge_idx, preserve_nodes=True)
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.

# %%
graph = train_graph.remove_self_loop().add_self_loop()
adj = graph.adj().to_dense()

in_dim = feat.shape[1]

hid_dim = 512
out_dim = 512
n_layers = 2
n_adj = adj.shape[1]

loss_fn = F.binary_cross_entropy
output_activation = nn.Sigmoid()

best_val_roc = 0
eval_roc = 0
best_val_ap = 0
eval_ap = 0

model = TOCCA_link(in_dim, hid_dim, out_dim, n_adj, n_layers, use_mlp=False)
lr1 = 1e-3
wd1 = 0
wd2 = 1e-4
optimizer = th.optim.Adam(model.parameters(), lr=lr1, weight_decay=wd2)

N = graph.number_of_nodes()


for epoch in range(100):
    model.train()
    optimizer.zero_grad()

    dfr = 0.2
    der = 0.2

    graph1, feat1 = random_aug(graph, feat, 0.2, 0.2)
    graph2, feat2 = random_aug(graph, feat, 0.2, 0.2)

    graph1 = graph1.add_self_loop()
    graph2 = graph2.add_self_loop()

    z1, z2, logits_temp = model(graph1, feat1, graph2, feat2)
    
    logits = output_activation(logits_temp)
    
    c = th.mm(z1.T, z2)
    c1 = th.mm(z1.T, z1)
    c2 = th.mm(z2.T, z2)

    c = c / N
    c1 = c1 / N
    c2 = c2 / N

    loss_inv = -th.diagonal(c).sum()
    iden = th.tensor(np.eye(c.shape[0]))
    loss_dec1 = (iden - c1).pow(2).sum()
    loss_dec2 = (iden - c2).pow(2).sum()

    lambd1 = 10^2
    lambd2 = 1e-3

    loss_task = loss_fn(logits, adj)

    loss = loss_task + lambd1 * loss_inv + lambd2 * (loss_dec1 + loss_dec2)

    loss.backward()
    optimizer.step()

    model.eval()
    with th.no_grad():
        val_roc, val_ap = get_scores(val_edges, val_edges_false, logits)
        test_roc, test_ap = get_scores(test_edges, test_edges_false, logits)

        if val_roc >= best_val_roc:
            best_val_roc = val_roc
            if test_roc > eval_roc:
                eval_roc = test_roc
        
        if val_ap >= best_val_ap:
            best_val_ap = val_ap
            if test_ap > eval_ap:
                eval_ap = test_ap

    print('Epoch:{}, val_ap:{:.4f}, val_roc:{:4f}, test_ap:{:4f}, test_roc:{:4f}'.format(epoch, val_ap, val_roc, test_ap, test_roc))
    print('Linear evaluation AP:{:.4f}'.format(eval_ap))
    print('Linear evaluation ROC:{:.4f}'.format(eval_roc))
# Out:
# Epoch:0, val_ap:0.4956, val_roc:0.488775, test_ap:0.500527, test_roc:0.488114
# Linear evaluation AP:0.5005
# Linear evaluation ROC:0.4881
# Epoch:1, val_ap:0.5057, val_roc:0.490363, test_ap:0.513020, test_roc:0.504792
# Linear evaluation AP:0.5130
# Linear evaluation ROC:0.5048
# Epoch:2, val_ap:0.5291, val_roc:0.510328, test_ap:0.512731, test_roc:0.503181
# Linear evaluation AP:0.5130
# Linear evaluation ROC:0.5048
# Epoch:3, val_ap:0.5249, val_roc:0.509662, test_ap:0.515626, test_roc:0.510948
# Linear evaluation AP:0.5130
# Linear evaluation ROC:0.5048
# Epoch:4, val_ap:0.5462, val_roc:0.537484, test_ap:0.525902, test_roc:0.532856
# Linear evaluation AP:0.5259
# Linear evaluation ROC:0.5329
# Epoch:5, val_ap:0.5694, val_roc:0.551865, test_ap:0.537680, test_roc:0.531210
# Linear evaluation AP:0.5377
# Linear evaluation ROC:0.5329
# Epoch:6, val_ap:0.5905, val_roc:0.571424, test_ap:0.547057, test_roc:0.542999
# Linear evaluation AP:0.5471
# Linear evaluation ROC:0.5430
# Epoch:7, val_ap:0.5940, val_roc:0.571125, test_ap:0.572883, test_roc:0.568041
# Linear evaluation AP:0.5729
# Linear evaluation ROC:0.5430
# Epoch:8, val_ap:0.6127, val_roc:0.592628, test_ap:0.591485, test_roc:0.595041
# Linear evaluation AP:0.5915
# Linear evaluation ROC:0.5950
# Epoch:9, val_ap:0.6192, val_roc:0.597626, test_ap:0.597500, test_roc:0.594525
# Linear evaluation AP:0.5975
# Linear evaluation ROC:0.5950
# Epoch:10, val_ap:0.6268, val_roc:0.600888, test_ap:0.626648, test_roc:0.616771
# Linear evaluation AP:0.6266
# Linear evaluation ROC:0.6168
# Epoch:11, val_ap:0.6431, val_roc:0.620220, test_ap:0.623894, test_roc:0.612567
# Linear evaluation AP:0.6266
# Linear evaluation ROC:0.6168
# Epoch:12, val_ap:0.6671, val_roc:0.630132, test_ap:0.641240, test_roc:0.628170
# Linear evaluation AP:0.6412
# Linear evaluation ROC:0.6282
# Epoch:13, val_ap:0.6656, val_roc:0.636171, test_ap:0.652705, test_roc:0.643717
# Linear evaluation AP:0.6412
# Linear evaluation ROC:0.6437
# Epoch:14, val_ap:0.6857, val_roc:0.648006, test_ap:0.669427, test_roc:0.654029
# Linear evaluation AP:0.6694
# Linear evaluation ROC:0.6540
# Epoch:15, val_ap:0.7005, val_roc:0.678244, test_ap:0.684342, test_roc:0.674053
# Linear evaluation AP:0.6843
# Linear evaluation ROC:0.6741
# Epoch:16, val_ap:0.7181, val_roc:0.696398, test_ap:0.692807, test_roc:0.682416
# Linear evaluation AP:0.6928
# Linear evaluation ROC:0.6824
# Epoch:17, val_ap:0.7199, val_roc:0.688970, test_ap:0.708408, test_roc:0.690180
# Linear evaluation AP:0.7084
# Linear evaluation ROC:0.6824
# Epoch:18, val_ap:0.7273, val_roc:0.701061, test_ap:0.708316, test_roc:0.689267
# Linear evaluation AP:0.7084
# Linear evaluation ROC:0.6893
# Epoch:19, val_ap:0.7321, val_roc:0.699772, test_ap:0.723671, test_roc:0.703941
# Linear evaluation AP:0.7237
# Linear evaluation ROC:0.6893
# Epoch:20, val_ap:0.7312, val_roc:0.703679, test_ap:0.726051, test_roc:0.700578
# Linear evaluation AP:0.7237
# Linear evaluation ROC:0.7006
# Epoch:21, val_ap:0.7594, val_roc:0.721192, test_ap:0.742104, test_roc:0.721760
# Linear evaluation AP:0.7421
# Linear evaluation ROC:0.7218
# Epoch:22, val_ap:0.7463, val_roc:0.715312, test_ap:0.747497, test_roc:0.722464
# Linear evaluation AP:0.7421
# Linear evaluation ROC:0.7218
# Epoch:23, val_ap:0.7676, val_roc:0.734036, test_ap:0.765441, test_roc:0.744948
# Linear evaluation AP:0.7654
# Linear evaluation ROC:0.7449
# Epoch:24, val_ap:0.7643, val_roc:0.741068, test_ap:0.769496, test_roc:0.751074
# Linear evaluation AP:0.7654
# Linear evaluation ROC:0.7511
# Epoch:25, val_ap:0.7742, val_roc:0.745857, test_ap:0.789791, test_roc:0.771370
# Linear evaluation AP:0.7898
# Linear evaluation ROC:0.7714
# Epoch:26, val_ap:0.7978, val_roc:0.767532, test_ap:0.790939, test_roc:0.770049
# Linear evaluation AP:0.7909
# Linear evaluation ROC:0.7714
# Epoch:27, val_ap:0.7987, val_roc:0.769037, test_ap:0.806731, test_roc:0.778974
# Linear evaluation AP:0.8067
# Linear evaluation ROC:0.7790
# Epoch:28, val_ap:0.8004, val_roc:0.772879, test_ap:0.811409, test_roc:0.783096
# Linear evaluation AP:0.8114
# Linear evaluation ROC:0.7831
# Epoch:29, val_ap:0.7967, val_roc:0.769174, test_ap:0.801899, test_roc:0.778709
# Linear evaluation AP:0.8114
# Linear evaluation ROC:0.7831
# Epoch:30, val_ap:0.8098, val_roc:0.778957, test_ap:0.810634, test_roc:0.785112
# Linear evaluation AP:0.8114
# Linear evaluation ROC:0.7851
# Epoch:31, val_ap:0.8044, val_roc:0.782554, test_ap:0.812618, test_roc:0.789344
# Linear evaluation AP:0.8114
# Linear evaluation ROC:0.7893
# Epoch:32, val_ap:0.8003, val_roc:0.772606, test_ap:0.816131, test_roc:0.792556
# Linear evaluation AP:0.8114
# Linear evaluation ROC:0.7893
# Epoch:33, val_ap:0.8122, val_roc:0.789698, test_ap:0.815442, test_roc:0.789695
# Linear evaluation AP:0.8154
# Linear evaluation ROC:0.7897
# Epoch:34, val_ap:0.8068, val_roc:0.780016, test_ap:0.823088, test_roc:0.796046
# Linear evaluation AP:0.8154
# Linear evaluation ROC:0.7897
# Epoch:35, val_ap:0.8087, val_roc:0.776707, test_ap:0.827486, test_roc:0.801368
# Linear evaluation AP:0.8154
# Linear evaluation ROC:0.7897
# Epoch:36, val_ap:0.8200, val_roc:0.786634, test_ap:0.831991, test_roc:0.804921
# Linear evaluation AP:0.8320
# Linear evaluation ROC:0.7897
# Epoch:37, val_ap:0.8241, val_roc:0.790209, test_ap:0.832563, test_roc:0.809746
# Linear evaluation AP:0.8326
# Linear evaluation ROC:0.8097
# Epoch:38, val_ap:0.8330, val_roc:0.803049, test_ap:0.840168, test_roc:0.813905
# Linear evaluation AP:0.8402
# Linear evaluation ROC:0.8139
# Epoch:39, val_ap:0.8386, val_roc:0.806362, test_ap:0.842467, test_roc:0.815384
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:40, val_ap:0.8296, val_roc:0.802495, test_ap:0.838943, test_roc:0.814357
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:41, val_ap:0.8321, val_roc:0.800799, test_ap:0.843150, test_roc:0.819246
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:42, val_ap:0.8222, val_roc:0.795509, test_ap:0.839553, test_roc:0.813038
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:43, val_ap:0.8238, val_roc:0.793226, test_ap:0.842045, test_roc:0.815711
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:44, val_ap:0.8271, val_roc:0.801422, test_ap:0.840961, test_roc:0.814557
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:45, val_ap:0.8317, val_roc:0.801587, test_ap:0.844345, test_roc:0.817490
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:46, val_ap:0.8348, val_roc:0.801396, test_ap:0.845580, test_roc:0.819193
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:47, val_ap:0.8387, val_roc:0.803672, test_ap:0.840512, test_roc:0.815148
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:48, val_ap:0.8337, val_roc:0.803575, test_ap:0.846105, test_roc:0.820195
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:49, val_ap:0.8356, val_roc:0.801396, test_ap:0.855513, test_roc:0.831851
# Linear evaluation AP:0.8425
# Linear evaluation ROC:0.8154
# Epoch:50, val_ap:0.8411, val_roc:0.814596, test_ap:0.852976, test_roc:0.830958
# Linear evaluation AP:0.8530
# Linear evaluation ROC:0.8310
# Epoch:51, val_ap:0.8393, val_roc:0.811727, test_ap:0.850739, test_roc:0.830086
# Linear evaluation AP:0.8530
# Linear evaluation ROC:0.8310
# Epoch:52, val_ap:0.8447, val_roc:0.818550, test_ap:0.853818, test_roc:0.832066
# Linear evaluation AP:0.8538
# Linear evaluation ROC:0.8321
# Epoch:53, val_ap:0.8421, val_roc:0.814643, test_ap:0.852486, test_roc:0.831307
# Linear evaluation AP:0.8538
# Linear evaluation ROC:0.8321
# Epoch:54, val_ap:0.8451, val_roc:0.816087, test_ap:0.858494, test_roc:0.837353
# Linear evaluation AP:0.8585
# Linear evaluation ROC:0.8321
# Epoch:55, val_ap:0.8428, val_roc:0.810816, test_ap:0.855321, test_roc:0.832344
# Linear evaluation AP:0.8585
# Linear evaluation ROC:0.8321
# Epoch:56, val_ap:0.8474, val_roc:0.818373, test_ap:0.859236, test_roc:0.836640
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8321
# Epoch:57, val_ap:0.8514, val_roc:0.823292, test_ap:0.857014, test_roc:0.833790
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:58, val_ap:0.8387, val_roc:0.812313, test_ap:0.854774, test_roc:0.829239
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:59, val_ap:0.8421, val_roc:0.813808, test_ap:0.855526, test_roc:0.831000
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:60, val_ap:0.8395, val_roc:0.814855, test_ap:0.856298, test_roc:0.832988
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:61, val_ap:0.8452, val_roc:0.817041, test_ap:0.856480, test_roc:0.834621
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:62, val_ap:0.8497, val_roc:0.820606, test_ap:0.857354, test_roc:0.835763
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:63, val_ap:0.8437, val_roc:0.812007, test_ap:0.860798, test_roc:0.839649
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:64, val_ap:0.8455, val_roc:0.816145, test_ap:0.861594, test_roc:0.839017
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:65, val_ap:0.8442, val_roc:0.816667, test_ap:0.862021, test_roc:0.841958
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:66, val_ap:0.8418, val_roc:0.811827, test_ap:0.861711, test_roc:0.840238
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:67, val_ap:0.8433, val_roc:0.816004, test_ap:0.860565, test_roc:0.840569
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:68, val_ap:0.8435, val_roc:0.814758, test_ap:0.858940, test_roc:0.835431
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:69, val_ap:0.8453, val_roc:0.816559, test_ap:0.852823, test_roc:0.828574
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:70, val_ap:0.8451, val_roc:0.816278, test_ap:0.854316, test_roc:0.829856
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:71, val_ap:0.8455, val_roc:0.816832, test_ap:0.854698, test_roc:0.829660
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:72, val_ap:0.8436, val_roc:0.816062, test_ap:0.858956, test_roc:0.835520
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:73, val_ap:0.8457, val_roc:0.817149, test_ap:0.861683, test_roc:0.841376
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:74, val_ap:0.8413, val_roc:0.813718, test_ap:0.860154, test_roc:0.839735
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:75, val_ap:0.8385, val_roc:0.809653, test_ap:0.857250, test_roc:0.836943
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:76, val_ap:0.8456, val_roc:0.813696, test_ap:0.858362, test_roc:0.835588
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:77, val_ap:0.8434, val_roc:0.811917, test_ap:0.856004, test_roc:0.831959
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:78, val_ap:0.8420, val_roc:0.812256, test_ap:0.853654, test_roc:0.830848
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:79, val_ap:0.8427, val_roc:0.812749, test_ap:0.854420, test_roc:0.832264
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:80, val_ap:0.8433, val_roc:0.814024, test_ap:0.859831, test_roc:0.837824
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:81, val_ap:0.8423, val_roc:0.812670, test_ap:0.860877, test_roc:0.837920
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:82, val_ap:0.8415, val_roc:0.814805, test_ap:0.862136, test_roc:0.839905
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:83, val_ap:0.8407, val_roc:0.811320, test_ap:0.856758, test_roc:0.835551
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:84, val_ap:0.8456, val_roc:0.815957, test_ap:0.855897, test_roc:0.833206
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:85, val_ap:0.8448, val_roc:0.817740, test_ap:0.858322, test_roc:0.834989
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:86, val_ap:0.8421, val_roc:0.813804, test_ap:0.858149, test_roc:0.836415
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:87, val_ap:0.8437, val_roc:0.815090, test_ap:0.859973, test_roc:0.837053
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:88, val_ap:0.8417, val_roc:0.813732, test_ap:0.856400, test_roc:0.835599
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:89, val_ap:0.8364, val_roc:0.807733, test_ap:0.856495, test_roc:0.835108
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:90, val_ap:0.8368, val_roc:0.809422, test_ap:0.853591, test_roc:0.829528
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:91, val_ap:0.8399, val_roc:0.810643, test_ap:0.854013, test_roc:0.832416
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:92, val_ap:0.8420, val_roc:0.810945, test_ap:0.854231, test_roc:0.832012
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:93, val_ap:0.8426, val_roc:0.812929, test_ap:0.857782, test_roc:0.838132
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:94, val_ap:0.8383, val_roc:0.808907, test_ap:0.860810, test_roc:0.839048
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:95, val_ap:0.8340, val_roc:0.806009, test_ap:0.856227, test_roc:0.834590
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:96, val_ap:0.8366, val_roc:0.808986, test_ap:0.854596, test_roc:0.831972
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:97, val_ap:0.8368, val_roc:0.809058, test_ap:0.856741, test_roc:0.833273
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:98, val_ap:0.8400, val_roc:0.810254, test_ap:0.856677, test_roc:0.835003
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
# Epoch:99, val_ap:0.8386, val_roc:0.808940, test_ap:0.853390, test_roc:0.831810
# Linear evaluation AP:0.8592
# Linear evaluation ROC:0.8338
